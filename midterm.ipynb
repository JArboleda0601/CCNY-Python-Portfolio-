# %%
import pandas as pd

# %%
WWE_df = pd.read_csv('data.csv')

# %%
WWE_df
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                           link  \
# 0       Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)
# 1           New York, NY         /wiki/Bruno_Sammartino
# ...

# %%
WWE_df.head(10)
# Out:
#                      name  reign  days       date               event  \
# 0            Buddy Rogers      1    36  11-Apr-63          House show
# 1        Bruno Sammartino      1  2803  17-May-63          House show
# 2             Ivan Koloff      1    21  18-Jan-71          House show
# 3           Pedro Morales      1  1027   8-Feb-71          House show
# 4            Stan Stasiak      1     9   1-Dec-73          House show
# 5        Bruno Sammartino      2  1237  10-Dec-73          House show
# 6  Superstar Billy Graham      1   296  30-Apr-77          House show
# 7            Bob Backlund      1   648  20-Feb-78  WWF on MSG Network
# 8           Antonio Inoki      1     6  30-Nov-79          House show
# 9            Bob Backlund      2  1470  17-Dec-79  WWF on MSG Network
#
#            location                           link              belt  \
# 0  Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)  WWE Championship
# ...

# %%
WWE_df.tail(10)
# Out:
#                 name  reign  days       date                          event  \
# 402         Carmella      1   131  10-Apr-18                      SmackDown
# 403  Charlotte Flair      2    28  19-Aug-18                     SummerSlam
# 404      Becky Lynch      2    91  16-Sep-18                 Hell in a Cell
# 405            Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
# 406  Charlotte Flair      3    13  26-Mar-19                      SmackDown
# 407      Becky Lynch      3    41   8-Apr-19                WrestleMania 35
# 408  Charlotte Flair      4     0  19-May-19              Money in the Bank
# 409           Bayley      1   140  19-May-19              Money in the Bank
# 410  Charlotte Flair      5     5   6-Oct-19                 Hell in a Cell
# 411           Bayley      2   247  11-Oct-19                      SmackDown
#
#                 location                       link  \
# 402      New Orleans, LA  /wiki/Carmella_(wrestler)
# ...

# %%
WWE_df.sample(10)
# Out:
#                    name  reign  days       date                 event  \
# 239           Ric Flair      3   133   1-Apr-79            House show
# 156  Sensational Sherri      1   441  24-Jul-87            Live event
# 157       Rockin' Robin      1   502   7-Oct-88  Prime Time Wrestling
# 236       Mr. Wrestling      1    21  19-Mar-78            House show
# 256      Wahoo McDaniel      5   167   7-Oct-84            House show
# 134         Randy Orton      9    49   2-Apr-17       WrestleMania 33
# 37       The Undertaker      2   133  23-Mar-97       WrestleMania 13
# 311         Lance Storm      2    36  23-Sep-00            House show
# 142       Bette Boucher      1    13  17-Sep-66            Live event
# 18           Hulk Hogan      3   248  24-Mar-91      WrestleMania VII
#
#             location                              link  \
# 239   Greensboro, NC                   /wiki/Ric_Flair
# 156      Houston, TX               /wiki/Sherri_Martel
# ...

# %%
WWE_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            412 non-null    object
#  1   reign           412 non-null    int64
#  2   days            412 non-null    int64
#  3   date            412 non-null    object
#  4   event           412 non-null    object
#  5   location        412 non-null    object
#  6   link            412 non-null    object
#  7   belt            412 non-null    object
#  8   date_of_birth   409 non-null    object
#  9   date_of_death   57 non-null     object
#  10  cause_of_death  27 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 35.5+ KB

# %%
WWE_df.describe()
# Out:
#             reign         days
# count  412.000000   412.000000
# mean     2.230583   136.475728
# std      1.847662   320.631967
# min      1.000000     0.000000
# 25%      1.000000    27.750000
# 50%      2.000000    69.000000
# 75%      3.000000   140.000000
# max     13.000000  3651.000000

# %%
WWE_df.describe(include='all')
# Out:
#              name       reign         days      date       event  \
# count         412  412.000000   412.000000       412         412
# unique        175         NaN          NaN       372         108
# top     John Cena         NaN          NaN  7-Oct-07  House show
# freq           18         NaN          NaN         4          51
# mean          NaN    2.230583   136.475728       NaN         NaN
# std           NaN    1.847662   320.631967       NaN         NaN
# min           NaN    1.000000     0.000000       NaN         NaN
# 25%           NaN    1.000000    27.750000       NaN         NaN
# 50%           NaN    2.000000    69.000000       NaN         NaN
# 75%           NaN    3.000000   140.000000       NaN         NaN
# max           NaN   13.000000  3651.000000       NaN         NaN
#
#             location             link                            belt  \
# count            412              412                             412
# ...

# %%
WWE_df['name'].value_counts()[:10]
# Out:
# name
# John Cena                  18
# Randy Orton                10
# Bret Hart                  10
# Triple H                    9
# The Rock                    8
# Ric Flair                   8
# Trish Stratus               7
# The Fabulous Moolah         7
# Charlotte Flair             7
# Stone Cold Steve Austin     6
# Name: count, dtype: int64

# %%
WWE_df['name'].value_counts()[:10].plot(kind='pie', title='Most Frequent Names')
# Out:
# <Axes: title={'center': 'Most Frequent Names'}, ylabel='count'>

# %%
WWE_df['event'].value_counts()
# Out:
# event
# House show                       51
# Raw                              49
# Nitro                            17
# SummerSlam                       17
# SmackDown                        17
#                                  ..
# Big Egg Wrestling Universe        1
# Bad Blood                         1
# Cyber Sunday                      1
# Vengeance: Night of Champions     1
# Stomping Grounds                  1
# Name: count, Length: 108, dtype: int64

# %%
WWE_df['event'].value_counts()[:5].plot(kind='bar', title= 'Events With Most Title Wins/Changes')
# Out:
# <Axes: title={'center': 'Events With Most Title Wins/Changes'}, xlabel='event'>

# %%
WWEdf['name']
# Out:
# 0          Buddy Rogers
# 1      Bruno Sammartino
# 2           Ivan Koloff
# 3         Pedro Morales
# 4          Stan Stasiak
#              ...
# 407         Becky Lynch
# 408     Charlotte Flair
# 409              Bayley
# 410     Charlotte Flair
# 411              Bayley
# Name: name, Length: 412, dtype: object

# %%
WWE_df.drop_duplicates(subset='name', inplace=True)

# %%
# Out:
#                  name  reign  days       date                          event  \
# 0        Buddy Rogers      1    36  11-Apr-63                     House show
# 1    Bruno Sammartino      1  2803  17-May-63                     House show
# 2         Ivan Koloff      1    21  18-Jan-71                     House show
# 3       Pedro Morales      1  1027   8-Feb-71                     House show
# 4        Stan Stasiak      1     9   1-Dec-73                     House show
# ..                ...    ...   ...        ...                            ...
# 394      Apollo Crews      1    20  25-May-20                            Raw
# 397             Naomi      1     9  12-Feb-17            Elimination Chamber
# 400           Natalya      1    86  20-Aug-17                     SummerSlam
# 402          Carmella      1   131  10-Apr-18                      SmackDown
# 405             Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
#
# ...
