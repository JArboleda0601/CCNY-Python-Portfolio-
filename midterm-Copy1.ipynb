# %%
import pandas as pd

# %%
WWE_df = pd.read_csv('data.csv')

# %%
WWE_df
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                           link  \
# 0       Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)
# 1           New York, NY         /wiki/Bruno_Sammartino
# ...

# %%
WWE_df.head(10)
# Out:
#                      name  reign  days       date               event  \
# 0            Buddy Rogers      1    36  11-Apr-63          House show
# 1        Bruno Sammartino      1  2803  17-May-63          House show
# 2             Ivan Koloff      1    21  18-Jan-71          House show
# 3           Pedro Morales      1  1027   8-Feb-71          House show
# 4            Stan Stasiak      1     9   1-Dec-73          House show
# 5        Bruno Sammartino      2  1237  10-Dec-73          House show
# 6  Superstar Billy Graham      1   296  30-Apr-77          House show
# 7            Bob Backlund      1   648  20-Feb-78  WWF on MSG Network
# 8           Antonio Inoki      1     6  30-Nov-79          House show
# 9            Bob Backlund      2  1470  17-Dec-79  WWF on MSG Network
#
#            location                           link              belt  \
# 0  Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)  WWE Championship
# ...

# %%
WWE_df.tail(10)
# Out:
#                 name  reign  days       date                          event  \
# 402         Carmella      1   131  10-Apr-18                      SmackDown
# 403  Charlotte Flair      2    28  19-Aug-18                     SummerSlam
# 404      Becky Lynch      2    91  16-Sep-18                 Hell in a Cell
# 405            Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
# 406  Charlotte Flair      3    13  26-Mar-19                      SmackDown
# 407      Becky Lynch      3    41   8-Apr-19                WrestleMania 35
# 408  Charlotte Flair      4     0  19-May-19              Money in the Bank
# 409           Bayley      1   140  19-May-19              Money in the Bank
# 410  Charlotte Flair      5     5   6-Oct-19                 Hell in a Cell
# 411           Bayley      2   247  11-Oct-19                      SmackDown
#
#                 location                       link  \
# 402      New Orleans, LA  /wiki/Carmella_(wrestler)
# ...

# %%
WWE_df.sample(10)
# Out:
#                  name  reign  days       date                          event  \
# 406   Charlotte Flair      3    13  26-Mar-19                      SmackDown
# 122      Brock Lesnar      4   224  17-Aug-14                     SummerSlam
# 63         Kurt Angle      2    15  23-Sep-01                     Unforgiven
# 204      Mickie James      5    23  31-Jan-10                   Royal Rumble
# 403   Charlotte Flair      2    28  19-Aug-18                     SummerSlam
# 373       Kevin Owens      2    66   2-May-17                      SmackDown
# 104           The Miz      1   160  22-Nov-10                            Raw
# 183              Jazz      2    64  27-Apr-03                       Backlash
# 202            Melina      3   154  25-Jan-09                   Royal Rumble
# 198  Candice Michelle      1   105  24-Jun-07  Vengeance: Night of Champions
#
#             location                    link  \
# 406   Uncasville, CT   /wiki/Charlotte_Flair
# ...

# %%
WWE_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            412 non-null    object
#  1   reign           412 non-null    int64
#  2   days            412 non-null    int64
#  3   date            412 non-null    object
#  4   event           412 non-null    object
#  5   location        412 non-null    object
#  6   link            412 non-null    object
#  7   belt            412 non-null    object
#  8   date_of_birth   409 non-null    object
#  9   date_of_death   57 non-null     object
#  10  cause_of_death  27 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 35.5+ KB

# %%
WWE_df.describe()
# Out:
#             reign         days
# count  412.000000   412.000000
# mean     2.230583   136.475728
# std      1.847662   320.631967
# min      1.000000     0.000000
# 25%      1.000000    27.750000
# 50%      2.000000    69.000000
# 75%      3.000000   140.000000
# max     13.000000  3651.000000

# %%
WWE_df.describe(include='all')
# Out:
#              name       reign         days      date       event  \
# count         412  412.000000   412.000000       412         412
# unique        175         NaN          NaN       372         108
# top     John Cena         NaN          NaN  7-Oct-07  House show
# freq           18         NaN          NaN         4          51
# mean          NaN    2.230583   136.475728       NaN         NaN
# std           NaN    1.847662   320.631967       NaN         NaN
# min           NaN    1.000000     0.000000       NaN         NaN
# 25%           NaN    1.000000    27.750000       NaN         NaN
# 50%           NaN    2.000000    69.000000       NaN         NaN
# 75%           NaN    3.000000   140.000000       NaN         NaN
# max           NaN   13.000000  3651.000000       NaN         NaN
#
#             location             link                            belt  \
# count            412              412                             412
# ...

# %%
WWE_df['name'].value_counts()[:10]
# Out:
# name
# John Cena                  18
# Randy Orton                10
# Bret Hart                  10
# Triple H                    9
# The Rock                    8
# Ric Flair                   8
# Trish Stratus               7
# The Fabulous Moolah         7
# Charlotte Flair             7
# Stone Cold Steve Austin     6
# Name: count, dtype: int64

# %%
WWE_df['name'].value_counts()[:10].plot(kind='pie', title='Most Frequent Names')
# Out:
# <Axes: title={'center': 'Most Frequent Names'}, ylabel='count'>

# %%
WWE_df['event'].value_counts()
# Out:
# event
# House show                       51
# Raw                              49
# Nitro                            17
# SummerSlam                       17
# SmackDown                        17
#                                  ..
# Big Egg Wrestling Universe        1
# Bad Blood                         1
# Cyber Sunday                      1
# Vengeance: Night of Champions     1
# Stomping Grounds                  1
# Name: count, Length: 108, dtype: int64

# %%
WWE_df['event'].value_counts()[:5].plot(kind='bar', title= 'Events With Most Title Wins/Changes')
# Out:
# <Axes: title={'center': 'Events With Most Title Wins/Changes'}, xlabel='event'>

# %%
WWE_df['name']
# Out:
# 0          Buddy Rogers
# 1      Bruno Sammartino
# 2           Ivan Koloff
# 3         Pedro Morales
# 4          Stan Stasiak
#              ...
# 407         Becky Lynch
# 408     Charlotte Flair
# 409              Bayley
# 410     Charlotte Flair
# 411              Bayley
# Name: name, Length: 412, dtype: object

# %%
WWE_df.drop_duplicates(subset='name', inplace=True)

# %%
WWE_df
# Out:
#                  name  reign  days       date                          event  \
# 0        Buddy Rogers      1    36  11-Apr-63                     House show
# 1    Bruno Sammartino      1  2803  17-May-63                     House show
# 2         Ivan Koloff      1    21  18-Jan-71                     House show
# 3       Pedro Morales      1  1027   8-Feb-71                     House show
# 4        Stan Stasiak      1     9   1-Dec-73                     House show
# ..                ...    ...   ...        ...                            ...
# 394      Apollo Crews      1    20  25-May-20                            Raw
# 397             Naomi      1     9  12-Feb-17            Elimination Chamber
# 400           Natalya      1    86  20-Aug-17                     SummerSlam
# 402          Carmella      1   131  10-Apr-18                      SmackDown
# 405             Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
#
# ...

# %%
WWE_df.loc[WWE_df['reign'] == 1, ['name', 'days']][:10].sort_values(by=['days'], ascending = False)
# Out:
#                       name  days
# 1         Bruno Sammartino  2803
# 11              Hulk Hogan  1474
# 3            Pedro Morales  1027
# 7             Bob Backlund   648
# 6   Superstar Billy Graham   296
# 0             Buddy Rogers    36
# 10          The Iron Sheik    28
# 2              Ivan Koloff    21
# 4             Stan Stasiak     9
# 8            Antonio Inoki     6

# %%
WWE_df.loc[WWE_df['belt'] == "WWE Women's Championship", ["name", "days"]][:10].sort_values(by=["days"], ascending = False)
# Out:
#                     name  days
# 141  The Fabulous Moolah  3651
# 156   Sensational Sherri   441
# 153      The Spider Lady   220
# 150        Wendi Richter   210
# 151          Leilani Kai    41
# 144         Yukiko Tomoe    23
# 142        Bette Boucher    13
# 154      Velvet McIntyre     6
# 146            Sue Green     2
# 148       Evelyn Stevens     2

# %%
filtering_condition = WWE_df['belt'] == "WWE SmackDown Women's Championship"
WWE_df_subset = WWE_df.loc[filtering_condition]

# %%
WWE_df_subset
# Out:
#          name  reign  days       date                          event  \
# 397     Naomi      1     9  12-Feb-17            Elimination Chamber
# 400   Natalya      1    86  20-Aug-17                     SummerSlam
# 402  Carmella      1   131  10-Apr-18                      SmackDown
# 405     Asuka      1   100  16-Dec-18  TLC: Tables, Ladders & Chairs
#
#             location                       link  \
# 397      Phoenix, AZ     /wiki/Naomi_(wrestler)
# 400     Brooklyn, NY     /wiki/Natalya_Neidhart
# 402  New Orleans, LA  /wiki/Carmella_(wrestler)
# 405     San Jose, CA     /wiki/Asuka_(wrestler)
#
#                                    belt date_of_birth date_of_death  \
# 397  WWE SmackDown Women's Championship    11/30/1987           NaN
# 400  WWE SmackDown Women's Championship     5/27/1982           NaN
# 402  WWE SmackDown Women's Championship    10/23/1987           NaN
# 405  WWE SmackDown Women's Championship     9/26/1981           NaN
#
#     cause_of_death
# ...

# %%
WWE_df['belt'].value_counts()
# Out:
# belt
# WWE United States Championship        74
# WWE Championship                      55
# WWE Women's Championship              34
# WWE Raw Women's Championship           8
# WWE SmackDown Women's Championship     4
# Name: count, dtype: int64

# %%
WWE_df.loc[WWE_df['belt'] == "WWE SmackDown Women's Championship", ["name", "days"]].sort_values(by=["days"], ascending = False)
# Out:
#          name  days
# 402  Carmella   131
# 405     Asuka   100
# 400   Natalya    86
# 397     Naomi     9

# %%
WWE_df.loc[WWE_df['belt'] == "WWE United States Championship", ["name", "days"]].sort_values(by=["days"], ascending = False)
# Out:
#                          name  days
# 270                 Rick Rude   378
# 340  Montel Vontavious Porter   343
# 260             Nikita Koloff   328
# 263             Barry Windham   283
# 342          Shelton Benjamin   240
# ..                        ...   ...
# 265             Michael Hayes    15
# 319                    Tajiri    13
# 312              Gen. Rection    12
# 365                   Kalisto     1
# 289                     Raven     1
#
# [74 rows x 2 columns]

# %%
WWE_df.loc[WWE_df['belt'] == "WWE Raw Women's Championship", ["name", "days"]].sort_values(by=["days"], ascending = False)
# Out:
#                 name  days
# 222      Becky Lynch   373
# 221     Ronda Rousey   232
# 208        Charlotte   113
# 216      Alexa Bliss   112
# 215           Bayley    76
# 219          Nia Jax    70
# 212  Charlotte Flair    29
# 209      Sasha Banks    27

# %%
WWE_df['location'].value_counts()[:5].plot(kind='line', title= 'Locations With Most Title Activity')
# Out:
# <Axes: title={'center': 'Locations With Most Title Activity'}, xlabel='location'>
